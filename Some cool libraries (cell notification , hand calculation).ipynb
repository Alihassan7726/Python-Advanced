# %% [markdown]
# # Time Push notifications

# %%
# Notify us for long running cells
#pip install jupyternotify


#autonotify also takes the arguments --message / -m and --output / -o.
# Out:
# ...
#   Created wheel for jupyternotify: filename=jupyternotify-0.1.15-py3-none-any.whl size=8721 sha256=13bbf5629cb3daf7e47151e3d35da1cf99ba30e8a81948d2154c5e0e57a88c1b
#   Stored in directory: c:\users\ali\appdata\local\pip\cache\wheels\2d\ff\e5\bced088d6443a70f72ee86f9e46f11056c981100c2d3cfadfb
# Successfully built jupyternotify
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %load_ext jupyternotify

# %%
# %%notify
# df = pd.read_excel(r'C:/BEPEC Python Material/Machine Learning/Logistic Regression/credit_card.xlsx',engine='openpyxl')
# df
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000    2          2         1   24      2      2
# 2              2     120000    2          2         2   26      0      2
# 3              3      90000    2          2         2   34      0      0
# 4              4      50000    2          2         1   37      0      0
# ...          ...        ...  ...        ...       ...  ...    ...    ...
# 29996      29996     220000    1          3         1   39      0      0
# 29997      29997     150000    1          3         2   43      0      0
# 29998      29998      30000    1          2         2   37      4      3
# 29999      29999      80000    1          3         1   41      1      0
# 30000      30000      50000    1          2         1   46      0      0
#
#           X8     X9  ...        X15        X16        X17       X18       X19  \
# ...

# %%
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
# %%notify
# import time
# time.sleep(5)
# Out:
# UsageError: Cell magic `%%notify` not found.

# %%
# %%notify -m "Waooo the msg works"
# time.sleep(5)

# %%
# %%notify -o
# accuracy = "99.99%"
# 'The answer is {}.'.format(accuracy) # To show output in notification
# Out:
# 'The answer is 99.99%.'

# %%
import numpy as np
import time
# autonotify on completion for cells that run longer than 8 seconds
# %autonotify -a 8

# %%
df = pd.read_excel(r'C:/BEPEC Python Material/Machine Learning/Logistic Regression/credit_card.xlsx',engine='openpyxl')
df
# Out:
#       Unnamed: 0         X1   X2         X3        X4   X5     X6     X7  \
# 0             ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2
# 1              1      20000    2          2         1   24      2      2
# 2              2     120000    2          2         2   26      0      2
# 3              3      90000    2          2         2   34      0      0
# 4              4      50000    2          2         1   37      0      0
# ...          ...        ...  ...        ...       ...  ...    ...    ...
# 29996      29996     220000    1          3         1   39      0      0
# 29997      29997     150000    1          3         2   43      0      0
# 29998      29998      30000    1          2         2   37      4      3
# 29999      29999      80000    1          3         1   41      1      0
# 30000      30000      50000    1          2         1   46      0      0
#
#           X8     X9  ...        X15        X16        X17       X18       X19  \
# ...

# %% [markdown]
# # Hand Calculations
# Documentation : https://github.com/connorferster/handcalcs

# %%
pip install handcalcs
# Out:
# ...
#
# ...
#   Attempting uninstall: nbconvert
#     Found existing installation: nbconvert 6.0.7
#     Uninstalling nbconvert-6.0.7:
#       Successfully uninstalled nbconvert-6.0.7
# ...

# %%
import handcalcs.render

# %%
# %%render
# a = 2
# b = 3
# c = 2*a + b/3
# Out:
# \[
# \begin{aligned}
# a &= 2 \;
# \\[10pt]
# b &= 3 \;
# \\[10pt]
# c &= 2 \cdot a + \frac{ b }{ 3 }  = 2 \cdot 2 + \frac{ 3 }{ 3 } &= 5.0
# \end{aligned}
# \]

# %%
# %%render
# x = 25
# a = np.power(x,2)
# Out:
# \[
# \begin{aligned}
# x &= 25 \;
# \\[10pt]
# a &= \mathrm{np.power} { \left( x ,\  2 \right) }  = np.power { \left( 25 ,\  2 \right) } &= 625
# \end{aligned}
# \]

# %%
from math import sqrt, pi

# %%
# %%render
# a = 2 / 3 * sqrt(pi)
# Out:
# \[
# \begin{aligned}
# a &= \frac{ 2 }{ 3 } \cdot \sqrt { \pi }  = \frac{ 2 }{ 3 } \cdot \sqrt { 3.142 } &= 1.182
# \end{aligned}
# \]

# %%
# %%tex
# a = 2 / 3 * sqrt(pi)
# Out:
# \[
# \begin{aligned}
# a &= \frac{ 2 }{ 3 } \cdot \sqrt { \pi }  = \frac{ 2 }{ 3 } \cdot \sqrt { 3.142 } &= 1.182
# \end{aligned}
# \]

# %% [markdown]
# # Importing all libraires automatically

# %%
# pyforest is used

# %%
df = pd.read_csv('../churn modeling/ml_case_training_data.csv')
df.head()
# Out:
#                                  id                      activity_new  ...                         origin_up  pow_max
# 0  48ada52261e7cf58715202705a0451c9  esoiiifxdlbkcsluxmfuacbdckommixw  ...  ldkssxwpmemidmecebumciepifcamkci  180.000
# 1  24011ae4ebbe3035111d65fa7c15bc57                               NaN  ...  lxidpiddsbxsbosboudacockeimpuepw   43.648
# 2  d29c2c54acc38ff3c0614d0a653813dd                               NaN  ...  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.800
# 3  764c75f661154dac3a6c254cd082ea7d                               NaN  ...  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.856
# 4  bba03439a292a1e166f80264c16191cb                               NaN  ...  kamkkxfxxuwbdslkwifmmcsiusiuosws   13.200
#
# [5 rows x 32 columns]

# %%
sns.distplot(df['cons_12m'])
# Out:
# C:\Users\Ali\.conda\envs\tensor_ali\lib\site-packages\seaborn\distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='cons_12m', ylabel='Density'>

# %%
active_imports()
# Out:
# import seaborn as sns
# import pandas as pd
# ['import seaborn as sns', 'import pandas as pd']
